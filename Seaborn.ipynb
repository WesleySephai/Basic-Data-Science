# %% [markdown]
# ## Seaborn practical

# %%
# Perform isnstallation
# conda install seaborn ..........in anaconda propmpt
# pip install seaborn ..................in terminal

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %% [markdown]
# ## Seaborn Line plot

# %%
# Sample data (replace this with your own DataFrame)
data = {
    'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
    'Temperature': [25, 26, 27, 28, 29]
}

# Create a DataFrame
dfsample = pd.DataFrame(data)

# Create a line plot using Seaborn
sns.lineplot(data=dfsample, x='Day', y='Temperature', marker='o', color='blue')

# Add title and labels
plt.title("Temperature Variation by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Temperature (°C)")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
### Activity ####
### Try to change temperature values and redraw the lineplot ###

# %%
df = pd.read_csv('Telco-Churn.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
numerical_columns = df.select_dtypes(include=['number'])

# Display numerical columns
print(numerical_columns)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0                 0       1           29.85
# 1                 0      34           56.95
# 2                 0       2           53.85
# 3                 0      45           42.30
# 4                 0       2           70.70
# ...             ...     ...             ...
# 7038              0      24           84.80
# 7039              0      72          103.20
# 7040              0      11           29.60
# 7041              1       4           74.40
# 7042              0      66          105.65
#
# [7043 rows x 3 columns]

# %%
# Create a line plot using Seaborn
sns.lineplot(data=df, x='tenure', y='MonthlyCharges',hue='Churn')#hue parameter is used to give the differentiation in the plot based on the categorical variable churn

# Add title and labels
plt.title("Tenure vs Monthly Charges")
plt.xlabel("Tenure (months)")
plt.ylabel("Monthly Charges ($)")

# Show the plot
plt.show()

# %%
# Draw line plot of size and total_bill with parameters
sns.lineplot(data=df, x='tenure', y='MonthlyCharges',
            style = 'gender', palette = "hot", dashes = False, 
            markers = ["o", "<"],  legend="brief",)
#The style parameter allows you to differentiate between different groups or categories 
plt.title("Line Plot", fontsize = 20) # for title
plt.xlabel("Size", fontsize = 15) # label for x-axis
plt.ylabel("Total Bill", fontsize = 15) # label for y-axis
plt.show()

# %% [markdown]
# ## Seaborn Scatter plots

# %%
# Sample DataFrame (you can replace this with your own DataFrame)
data = {
    'x': [1, 2, 3, 4, 5],
    'y': [2, 4, 6, 8, 10]
}

# Create a DataFrame
df1 = pd.DataFrame(data)

# Create a scatter plot using Seaborn
sns.scatterplot(data=df1, x='x', y='y')

# Add title and labels
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
### Activity ####
### Try to data values and redraw the scatterplot ###

# %%
# Create a scatter plot using Seaborn
sns.scatterplot(data=df, x='tenure', y='MonthlyCharges',hue='Churn')

# Add title and labels
plt.title("Scatter Plot of Tenure vs Monthly Charges with Churn")
plt.xlabel("Tenure (months)")
plt.ylabel("Monthly Charges ($)")

# Show the plot
plt.show()

# %% [markdown]
# ## Categorical Plots
# 1. Bar Plots
# 2. Box Plots
# 3. Violin Plots
# 4. Count Plots

# %%
#Simple bar plot

# %%
# User-provided data (replace this with your own data)
databar = {
    'Grades': ['A', 'B', 'C', 'D'],
    'Count of students': [10, 20, 15, 25]
}

# Convert data to DataFrame
dfbar = pd.DataFrame(databar)

# Create a bar plot using Seaborn
sns.barplot(data=dfbar, x='Grades', y='Count of students')

# Add title and labels
plt.title("Bar Plot")
plt.xlabel("Grades")
plt.ylabel("Count of students")

# Show the plot
plt.show()

# %%
# Count the number of customers for each churn status
churn_counts = df['Churn'].value_counts()

# Create a DataFrame from the churn counts
churn_counts_df = pd.DataFrame({'Churn Status': churn_counts.index, 'Count': churn_counts.values})

# Create a bar plot using Seaborn
sns.barplot(data=churn_counts_df, x='Churn Status', y='Count')

# Add title and labels
plt.title("Churn Status of Telco Customers")
plt.xlabel("Churn Status")
plt.ylabel("Count")

# Show the plot
plt.show()

# %%
# Create a count plot using Seaborn
sns.countplot(df, x='Churn')

# Add title and labels
plt.title("Churn Status of Telco Customers")
plt.xlabel("Churn Status")
plt.ylabel("Count")

# Show the plot
plt.show()

# %%
#simple box plot

# %%
# User-provided data 
databox = {
    'Category': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C'],
    'Value': [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
}

# Convert data to DataFrame
dfbox = pd.DataFrame(databox)

# Create a box plot using Seaborn
sns.boxplot(data=dfbox, x='Category', y='Value')

# Add title and labels
plt.title("Box Plot")
plt.xlabel("Category")
plt.ylabel("Value")

# Show the plot
plt.show()

# %%
# Specify the columns you want to include in the box plots
columns_for_boxplot = ['tenure', 'MonthlyCharges', 'TotalCharges']

# Create box plots using Seaborn
sns.boxplot(data=df[columns_for_boxplot])

# Add title and labels
plt.title("Box Plots for Telco Churn Dataset")
plt.ylabel("Value")

# Show the plot
plt.show()

# %%
#Violin plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# User-provided data (replace this with your own data)
dataviolin = {
    'Category': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C'],
    'Value': [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
}

# Convert data to DataFrame
dfviolin = pd.DataFrame(dataviolin)

# Create a violin plot using Seaborn
sns.violinplot(data=dfviolin, x='Category', y='Value')

# Add title and labels
plt.title("Violin Plot")
plt.xlabel("Category")
plt.ylabel("Value")

# Show the plot
plt.show()

# %%
#count plot

# %%
# Create count plot using Seaborn
sns.countplot(data=df, x='Contract')

# Add title and labels
plt.title("Count of Customers by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Count")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# ## Outlier detection and removal using boxplot

# %%
# Create a synthetic dataset with outliers
np.random.seed(42)
dataoutlier = pd.DataFrame({
    'Category': np.random.choice(['A', 'B', 'C'], size=100),
    'Value': np.random.normal(loc=0, scale=1, size=100)
})
dataoutlier.loc[0:5, 'Value'] = 10  # Add outliers

# Create a box plot using Seaborn
sns.boxplot(data=dataoutlier, x='Category', y='Value')

# Add title and labels
plt.title("Box Plot with Outliers")
plt.xlabel("Category")
plt.ylabel("Value")

# Show the plot
plt.show()

# %%
# Generate synthetic data with outliers
np.random.seed(42)
data = np.concatenate([np.random.normal(loc=0, scale=1, size=80),
                       np.random.normal(loc=10, scale=1, size=20)])  # Add outliers

# Create a box plot to visualize the data and identify outliers
sns.boxplot(data=data)
plt.title("Box Plot of Data with Outliers")
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.show()

# Ask the user to specify a threshold for outlier removal
threshold = float(input("Enter the threshold for outlier removal: "))

# Detect outliers based on the user-defined threshold
outliers = data[(data < np.percentile(data, 25) - 1.5 * (np.percentile(data, 75) - np.percentile(data, 25))) |
                (data > np.percentile(data, 75) + 1.5 * (np.percentile(data, 75) - np.percentile(data, 25)))]

# Remove outliers based on the user-defined threshold
data_cleaned = data[(data >= np.percentile(data, 25) - threshold) & 
                    (data <= np.percentile(data, 75) + threshold)]

# Create a box plot to visualize the cleaned data without outliers
sns.boxplot(data=data_cleaned)
plt.title("Box Plot of Cleaned Data without Outliers")
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.show()

# Display the removed outliers
print("Outliers removed from the data:")
print(outliers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 14
#      11 plt.show()
#      13 # Ask the user to specify a threshold for outlier removal
# ---> 14 threshold = float(input("Enter the threshold for outlier removal: "))
#      16 # Detect outliers based on the user-defined threshold
#      17 outliers = data[(data < np.percentile(data, 25) - 1.5 * (np.percentile(data, 75) - np.percentile(data, 25))) |
#      18                 (data > np.percentile(data, 75) + 1.5 * (np.percentile(data, 75) - np.percentile(data, 25)))]
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
# ...

# %%
#Histogram

# %%
# User-provided data 
datahist = [10, 151, 120, 205, 350, 135, 340, 145, 250, 55]

# Create a histogram using Seaborn
sns.histplot(data=datahist, bins=5)

# Add title and labels
plt.title("Histogram Plot")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %%
# Plot histogram for a specific column (e.g., 'tenure')
sns.histplot(data=df, x='tenure', bins=20)

# Add title and labels
plt.title("Histogram of Tenure in Telco Churn Dataset")
plt.xlabel("Tenure (months)")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %% [markdown]
# Kernel Density Estimation Plots or KDE Plots

# %%
# Generate synthetic data
np.random.seed(0)
datakde = np.random.normal(loc=0, scale=1, size=1000)

# Create KDE plot using Seaborn
sns.kdeplot(datakde)

# Add title and labels
plt.title("Kernel Density Estimation (KDE) Plot")
plt.xlabel("Values")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
#Heatmaps

# %%
# Generate random data
dataheat = np.random.rand(5,5)

# Create heatmap using Seaborn
sns.heatmap(dataheat,annot=True, fmt=".2f", cmap="coolwarm")

# Add title
plt.title("Simple Heatmap")

# Show the plot
plt.show()

# %% [markdown]
# Try with other color cominations : plasma, inferno magma, bwr, tab10,tab20,terrain, ocean

# %%
# Replace blank spaces with NaN
df.replace(' ', np.nan, inplace=True)

# Drop rows with NaN values
df.dropna(inplace=True)
# Select numerical columns for correlation matrix
numerical_columns = ['tenure', 'MonthlyCharges', 'TotalCharges']

# Calculate correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Create heatmap using Seaborn
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm')

# Add title
plt.title("Correlation Heatmap of Numerical Variables in Telco Churn Dataset")

# Show the plot
plt.show()
